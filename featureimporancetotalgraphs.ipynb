# %%
RF1 = [205, 143, 9, 153, 241, 243, 179, 141, 117, 137]
ADA1 = [61, 205, 267, 45, 9, 55, 68, 139, 192, 15]
SVM1 = [173, 169, 174, 46, 211, 61, 243, 23, 90, 259]
GRAD1 = [192, 288, 137, 55, 205, 243, 73, 267, 64, 235]
TAB1 = [156, 243, 253, 105, 181, 33, 279, 15, 1, 47]
RF2 = [181, 197, 194, 61, 174, 17, 16, 209, 15, 192]
ADA2 = [17, 55, 7, 181, 61, 43, 15, 19, 197, 205]
SVM2 = []
GRAD2 = [194, 267, 55, 197, 26, 73, 16, 180, 288, 85]
TAB2 = [222, 172, 113, 111, 63, 105, 114, 128, 248, 293]
RF3 = [175, 14, 45, 15, 179, 17, 181, 57, 177, 43]
ADA3 = [15, 45, 175, 179, 174, 178, 17, 22, 61, 64]
SVM3 = [169, 268, 270, 122, 88, 130, 280, 278, 121, 123]
GRAD3 = [45, 55, 16, 179, 91, 15, 52, 174, 73, 79]
TAB3 = [181, 238, 275, 256, 99, 53, 241, 75, 127, 211]
RF4 = [194, 156, 153, 117, 181, 141, 151, 158, 119, 64]
ADA4 = [151, 179, 57, 45, 153, 180, 55, 15, 9, 176]
SVM4 = []
GRAD4 = [55, 117, 194, 14, 235, 247, 15, 25, 180, 36]
TAB4 =[1, 105, 7, 158, 185, 55, 207, 74, 51, 159]
RF5 = [192, 43, 194, 156, 181, 157, 185, 125, 17, 7]
ADA5 = [192, 181, 275, 194, 17, 15, 13, 197, 259, 187]
SVM5 = []
GRAD5 = [194, 197, 181, 117, 64, 153, 15, 273, 73, 180]
TAB5 = [255, 252, 58, 25, 153, 76, 186, 20, 168, 247]
video_1 = RF1 + ADA1 + SVM1 + GRAD1 + TAB1 + RF2 + ADA2 + SVM2 + GRAD2 + TAB2 + RF3 + ADA3 + SVM3 + GRAD3 + TAB3 + RF4 + ADA4 + SVM4 + GRAD4 + TAB4 + RF5 + ADA5 + SVM5 + GRAD5 + TAB5
vid1rf = RF1 + RF2 + RF3 + RF4 +RF5
vid1ada = ADA1 + ADA2 + ADA3 + ADA4 + ADA5
vid1svm = SVM1 + SVM2 + SVM3 + SVM4 + SVM5
vid1grad = GRAD1 + GRAD2 + GRAD3 + GRAD4 + GRAD5
vid1tab = TAB1 + TAB2 + TAB3 + TAB4 + TAB5
print(video_1)
# Out:
# [205, 143, 9, 153, 241, 243, 179, 141, 117, 137, 61, 205, 267, 45, 9, 55, 68, 139, 192, 15, 173, 169, 174, 46, 211, 61, 243, 23, 90, 259, 192, 288, 137, 55, 205, 243, 73, 267, 64, 235, 156, 243, 253, 105, 181, 33, 279, 15, 1, 47, 181, 197, 194, 61, 174, 17, 16, 209, 15, 192, 17, 55, 7, 181, 61, 43, 15, 19, 197, 205, 194, 267, 55, 197, 26, 73, 16, 180, 288, 85, 222, 172, 113, 111, 63, 105, 114, 128, 248, 293, 175, 14, 45, 15, 179, 17, 181, 57, 177, 43, 15, 45, 175, 179, 174, 178, 17, 22, 61, 64, 169, 268, 270, 122, 88, 130, 280, 278, 121, 123, 45, 55, 16, 179, 91, 15, 52, 174, 73, 79, 181, 238, 275, 256, 99, 53, 241, 75, 127, 211, 194, 156, 153, 117, 181, 141, 151, 158, 119, 64, 151, 179, 57, 45, 153, 180, 55, 15, 9, 176, 55, 117, 194, 14, 235, 247, 15, 25, 180, 36, 1, 105, 7, 158, 185, 55, 207, 74, 51, 159, 192, 43, 194, 156, 181, 157, 185, 125, 17, 7, 192, 181, 275, 194, 17, 15, 13, 197, 259, 187, 194, 197, 181, 117, 64, 153, 15, 273, 73, 180, 255, 252, 58, 25, 153, 76, 186, 20, 168
# ...

# %%
RF12 = [80, 62, 79, 64, 50, 83, 61, 63, 157, 2]
ADA12 = [63, 80, 56, 64, 75, 62, 58, 25, 21, 79]
SVM12 = [146, 36, 69, 46, 148, 262, 254, 252, 256, 84]
GRAD12 =[63, 238, 81, 286, 169, 194, 162, 259, 25, 62]
TAB12 = [69, 268, 18, 32, 293, 147, 38, 153, 243, 136]
RF22 = [64, 79, 60, 51, 63, 49, 157, 15, 81, 156]
ADA22 = [63, 64, 51, 81, 80, 62, 197, 79, 78, 49]
SVM22 =[ 43, 237, 271, 278, 291, 239, 115, 299, 297, 279] 
GRAD22 = [64, 63, 193, 51, 79, 272, 199, 224, 213, 30]
TAB22 = [145, 281, 298, 108, 159, 286, 48, 216, 186, 226]
RF32 = [80, 49, 62, 63, 78, 20, 51, 197, 45, 61]
ADA32 = [80, 62, 52, 63, 60, 73, 64, 171, 49, 173]
SVM32 = []
GRAD32 = [62, 79, 60, 204, 49, 66, 30, 238, 63, 75]
TAB32 = [109, 32, 219, 216, 273, 205, 221, 71, 25, 277]
RF42 = [63, 62, 73, 58, 80, 64, 78, 60, 56, 6]
ADA42 = [80, 62, 63, 78, 60, 61, 193, 64, 181, 81]
SVM42 = [237, 280, 129, 217, 221, 265, 295, 219, 287, 285] 
GRAD42 = [58, 51, 61, 62, 197, 66, 200, 30, 80, 4]
TAB42 = [162, 255, 22, 152, 71, 167, 141, 190, 127, 208]
RF52 = [60, 62, 64, 82, 58, 49, 156, 78, 213, 80]
ADA52 = [64, 62, 80, 60, 78, 57, 76, 63, 56, 156]
SVM52 = [252, 196, 231, 69, 295, 25, 287, 71, 285, 67] 
GRAD52 = [62, 156, 64, 51, 75, 159, 238, 61, 213, 44]
TAB52 = [297, 235, 126, 146, 299, 112, 14, 259, 30, 183]
video_2 = RF12 + ADA12 + SVM12 + GRAD12 + TAB12 + RF22 + ADA22 + SVM22 + GRAD22 + TAB22 + RF32 + ADA32 + SVM32 + GRAD32 + TAB32 + RF42 + ADA42 + SVM42 + GRAD42 + TAB42 + RF52 + ADA52 + SVM52 + GRAD52 + TAB52
vid2rf = RF12 + RF22 + RF32+ RF42 +RF52
vid2ada = ADA12 + ADA22 + ADA32 + ADA42 + ADA52
vid2svm = SVM12 + SVM22 + SVM32 + SVM42 + SVM52
vid2grad = GRAD12 + GRAD22 + GRAD32 + GRAD42 + GRAD52
vid2tab = TAB12 + TAB22 + TAB32 + TAB42 + TAB52
print(video_2)
# Out:
# [80, 62, 79, 64, 50, 83, 61, 63, 157, 2, 63, 80, 56, 64, 75, 62, 58, 25, 21, 79, 146, 36, 69, 46, 148, 262, 254, 252, 256, 84, 63, 238, 81, 286, 169, 194, 162, 259, 25, 62, 69, 268, 18, 32, 293, 147, 38, 153, 243, 136, 64, 79, 60, 51, 63, 49, 157, 15, 81, 156, 63, 64, 51, 81, 80, 62, 197, 79, 78, 49, 43, 237, 271, 278, 291, 239, 115, 299, 297, 279, 64, 63, 193, 51, 79, 272, 199, 224, 213, 30, 145, 281, 298, 108, 159, 286, 48, 216, 186, 226, 80, 49, 62, 63, 78, 20, 51, 197, 45, 61, 80, 62, 52, 63, 60, 73, 64, 171, 49, 173, 62, 79, 60, 204, 49, 66, 30, 238, 63, 75, 109, 32, 219, 216, 273, 205, 221, 71, 25, 277, 63, 62, 73, 58, 80, 64, 78, 60, 56, 6, 80, 62, 63, 78, 60, 61, 193, 64, 181, 81, 237, 280, 129, 217, 221, 265, 295, 219, 287, 285, 58, 51, 61, 62, 197, 66, 200, 30, 80, 4, 162, 255, 22, 152, 71, 167, 141, 190, 127, 208, 60, 62, 64, 82, 58, 49, 156, 78, 213, 80, 64, 62, 80, 60, 78, 57, 76, 63, 56, 156, 252, 196, 231, 69, 295, 25, 287, 71, 285, 67, 62, 156, 64, 51, 75, 159, 238, 6
# ...

# %%
RF13 = [200, 202, 226, 50, 208, 288, 66, 232, 198, 282]
ADA13 = [204, 202, 224, 200, 226, 222, 208, 179, 218, 74]
SVM13 = []
GRAD13 = [208, 58, 94, 149, 211, 138, 197, 20, 173, 242]
TAB13 = [113, 52, 41, 216, 270, 215, 292, 248, 175, 246]
RF23 = [202, 224, 208, 226, 222, 56, 220, 66, 231, 58]
ADA23 = [202, 208, 90, 200, 206, 222, 244, 76, 22, 228]
SVM23 = [ 58, 74, 10, 88, 34, 40, 52, 130, 76, 112] 
GRAD23 = [202, 58, 208, 94, 11, 149, 192, 195, 20, 22]
TAB23 = [287, 198, 188, 275, 90, 20, 241, 177, 59, 27]
RF33 = [208, 202, 226, 232, 204, 172, 206, 224, 200, 222]
ADA33 = [202, 206, 172, 204, 208, 232, 224, 226, 66, 149]
SVM33 = []
GRAD33 = [208, 58, 202, 71, 22, 172, 112, 273, 94, 299]
TAB33 = [280, 34, 13, 146, 290, 225, 0, 114, 3, 76]
RF43 = [204, 206, 138, 202, 230, 146, 220, 224, 208, 54]
ADA43 = [204, 202, 200, 230, 226, 208, 138, 76, 149, 92]
SVM43 = [180, 198, 204, 186, 262, 226, 258, 244, 222, 190]
GRAD43 = [58, 208, 202, 63, 94, 220, 11, 47, 70, 286]
TAB43 = [105, 37, 189, 74, 173, 90, 292, 148, 118, 119]
RF53 = [208, 204, 206, 222, 198, 202, 286, 226, 224, 50]
ADA53 = [208, 200, 222, 204, 198, 206, 224, 74, 2, 50]
SVM53 = []
GRAD53 = [198, 90, 208, 58, 66, 211, 163, 0, 63, 204]
TAB53 = [14, 180, 27, 222, 71, 263, 42, 20, 146, 139]

video_3 = RF13 + ADA13 + SVM13 + GRAD13 + TAB13 + RF23 + ADA23 + SVM23 + GRAD23 + TAB23 + RF33 + ADA33 + SVM33 + GRAD33 + TAB33 + RF43 + ADA43 + SVM43 + GRAD43 + TAB43 + RF53 + ADA53 + SVM53 + GRAD53 + TAB53
vid3rf = RF13 + RF23 + RF33 + RF43 +RF53
vid3ada = ADA13 + ADA23 + ADA33 + ADA43 + ADA53
vid3svm = SVM13 + SVM23 + SVM33 + SVM43 + SVM53
vid3grad = GRAD13 + GRAD23 + GRAD33 + GRAD43 + GRAD53
vid3tab = TAB13 + TAB23 + TAB33 + TAB43 + TAB53
print(video_3)
# Out:
# [200, 202, 226, 50, 208, 288, 66, 232, 198, 282, 204, 202, 224, 200, 226, 222, 208, 179, 218, 74, 208, 58, 94, 149, 211, 138, 197, 20, 173, 242, 113, 52, 41, 216, 270, 215, 292, 248, 175, 246, 202, 224, 208, 226, 222, 56, 220, 66, 231, 58, 202, 208, 90, 200, 206, 222, 244, 76, 22, 228, 58, 74, 10, 88, 34, 40, 52, 130, 76, 112, 202, 58, 208, 94, 11, 149, 192, 195, 20, 22, 287, 198, 188, 275, 90, 20, 241, 177, 59, 27, 208, 202, 226, 232, 204, 172, 206, 224, 200, 222, 202, 206, 172, 204, 208, 232, 224, 226, 66, 149, 208, 58, 202, 71, 22, 172, 112, 273, 94, 299, 280, 34, 13, 146, 290, 225, 0, 114, 3, 76, 204, 206, 138, 202, 230, 146, 220, 224, 208, 54, 204, 202, 200, 230, 226, 208, 138, 76, 149, 92, 180, 198, 204, 186, 262, 226, 258, 244, 222, 190, 58, 208, 202, 63, 94, 220, 11, 47, 70, 286, 105, 37, 189, 74, 173, 90, 292, 148, 118, 119, 208, 204, 206, 222, 198, 202, 286, 226, 224, 50, 208, 200, 222, 204, 198, 206, 224, 74, 2, 50, 198, 90, 208, 58, 66, 211, 163, 0, 63, 204, 14, 180, 27, 
# ...

# %%
RF14 = [83, 81, 231, 195, 62, 38, 68, 193, 72, 25]
ADA14 = [83, 68, 193, 229, 233, 60, 40, 30, 81, 231]
SVM14 = []
GRAD14 = [83, 233, 68, 137, 34, 64, 30, 193, 185, 79]
TAB14 = [83, 230, 246, 233, 90, 299, 44, 173, 89, 297]
RF24 = [81, 228, 229, 79, 64, 68, 30, 83, 71, 233]
ADA24 = [83, 81, 197, 229, 195, 79, 48, 64, 228, 30]
SVM24 = [202, 183, 211, 164, 148, 215, 88, 240, 287, 242] 
GRAD24 = [81, 64, 83, 224, 30, 228, 42, 216, 137, 186]
TAB24 = [184, 72, 156, 174, 254, 158, 29, 118, 150, 236]
RF34 = [81, 83, 193, 229, 78, 51, 64, 62, 47, 70]
ADA34 = [81, 83, 233, 64, 78, 28, 79, 68, 51, 229]
SVM34 = []
GRAD34 = [81, 64, 30, 193, 135, 134, 83, 27, 68, 137]
TAB34 =[62, 180, 150, 83, 188, 235, 47, 178, 177, 224]
RF44 = [83, 64, 228, 81, 78, 233, 197, 68, 195, 229]
ADA44 = [68, 83, 228, 229, 232, 196, 30, 81, 78, 64]
SVM44 = []
GRAD44 = [30, 64, 79, 83, 68, 81, 44, 104, 135, 186]
TAB44 = [298, 145, 133, 285, 25, 180, 218, 72, 5, 87]
RF54 = [83, 81, 231, 195, 62, 38, 68, 193, 72, 25]
ADA54 = [196, 81, 228, 83, 64, 233, 78, 197, 68, 79]
SVM54 = []
GRAD54 = [64, 83, 233, 137, 81, 224, 186, 37, 26, 191]
TAB54 = [64, 83, 233, 137, 81, 224, 186, 37, 26, 191]
video_4 = RF14 + ADA14 + SVM14 + GRAD14 + TAB14 + RF24 + ADA24 + SVM24 + GRAD24 + TAB24 + RF34 + ADA34 + SVM34 + GRAD34 + TAB34 + RF44 + ADA44 + SVM44 + GRAD44 + TAB44 + RF54 + ADA54 + SVM54 + GRAD54 + TAB54
vid4rf = RF14 + RF24 + RF34 + RF44 +RF54
vid4ada = ADA14 + ADA24 + ADA34 + ADA44 + ADA54
vid4svm = SVM14 + SVM24 + SVM34 + SVM44 + SVM54
vid4grad = GRAD14 + GRAD24 + GRAD34 + GRAD44 + GRAD54
vid4tab = TAB14 + TAB24 + TAB34 + TAB44 + TAB54
print(video_4)
# Out:
# [83, 81, 231, 195, 62, 38, 68, 193, 72, 25, 83, 68, 193, 229, 233, 60, 40, 30, 81, 231, 83, 233, 68, 137, 34, 64, 30, 193, 185, 79, 83, 230, 246, 233, 90, 299, 44, 173, 89, 297, 81, 228, 229, 79, 64, 68, 30, 83, 71, 233, 83, 81, 197, 229, 195, 79, 48, 64, 228, 30, 202, 183, 211, 164, 148, 215, 88, 240, 287, 242, 81, 64, 83, 224, 30, 228, 42, 216, 137, 186, 184, 72, 156, 174, 254, 158, 29, 118, 150, 236, 81, 83, 193, 229, 78, 51, 64, 62, 47, 70, 81, 83, 233, 64, 78, 28, 79, 68, 51, 229, 81, 64, 30, 193, 135, 134, 83, 27, 68, 137, 62, 180, 150, 83, 188, 235, 47, 178, 177, 224, 83, 64, 228, 81, 78, 233, 197, 68, 195, 229, 68, 83, 228, 229, 232, 196, 30, 81, 78, 64, 30, 64, 79, 83, 68, 81, 44, 104, 135, 186, 298, 145, 133, 285, 25, 180, 218, 72, 5, 87, 83, 81, 231, 195, 62, 38, 68, 193, 72, 25, 196, 81, 228, 83, 64, 233, 78, 197, 68, 79, 64, 83, 233, 137, 81, 224, 186, 37, 26, 191, 64, 83, 233, 137, 81, 224, 186, 37, 26, 191]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
plt.rcParams["figure.figsize"] = (5,5)
totalvids = video_1 + video_2 + video_3 + video_4
index = pd.Index(totalvids)
print(len(index))
top10 = ((pd.Index(totalvids)).value_counts())[:10]

vid1 = ((pd.Index(video_1)).value_counts())[:10]
vid2 = ((pd.Index(video_2)).value_counts())[:10]
vid3 = ((pd.Index(video_3)).value_counts())[:10]
vid4 = ((pd.Index(video_4)).value_counts())[:10]

totrf = vid1rf + vid2rf + vid3rf + vid4rf
totada = vid1ada + vid2ada + vid3ada + vid4ada
totsvm = vid1svm + vid2svm + vid3svm + vid4svm
totgrad = vid1grad + vid2grad + vid3grad + vid4grad
tottab = vid1tab + vid2tab + vid3tab + vid4tab

rf10 = ((pd.Index(totrf)).value_counts())[:10]
ada10 = ((pd.Index(totada)).value_counts())[:10]
svm10 = ((pd.Index(totsvm)).value_counts())[:10]
grad10 = ((pd.Index(totgrad)).value_counts())[:10]
tab10 = ((pd.Index(tottab)).value_counts())[:10]

sns.barplot(x=vid1.index, y=vid1)    
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features video 1")
plt.savefig('vid1.png')
plt.show()
sns.barplot(x=vid2.index, y=vid2)    
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features video 2")
plt.savefig('vid2.png')
plt.show()
sns.barplot(x=vid3.index, y=vid3)    
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features video 3")
plt.savefig('vid3.png')
plt.show()
sns.barplot(x=vid4.index, y=vid4)    
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features video 4")
plt.savefig('vid4.png')
plt.show()




sns.barplot(x=rf10.index, y=rf10)    
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features RF")
plt.savefig('rf10.png')
plt.show()
sns.barplot(x=ada10.index, y=ada10)
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features AdaBoost")
plt.savefig('ada10.png')
plt.show()
sns.barplot(x=svm10.index, y=svm10)
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features SVM")
plt.savefig('svm10.png')
plt.show()
sns.barplot(x=grad10.index, y=grad10)
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features GradientBoosting")
plt.savefig('grad10.png')
plt.show()
sns.barplot(x=tab10.index, y=tab10)
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features TabNet")
plt.savefig('tab10.png')
plt.show()
sns.barplot(x=top10.index, y=top10)
plt.ylabel('Number of times feature is used')
plt.xlabel('Feature name (numbers 0-299)')
plt.title("Top 10 influential features")
plt.savefig('top10.png')
plt.show()
# Out:
# 890

# %%
totalvids = video_1 + video_2 + video_3 + video_4
index = pd.Index(totalvids)
print(len(index))
counts = index.value_counts()
top10 = counts[:10]
# Out:
# 890

# %%
#top10.sort_values().plot(kind = 'bar')
#index.value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>
